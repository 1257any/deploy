# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
#from sklearn.metrics import accuracy_score,precision_score,\
#recall_score,confusion_matrix,roc_auc_score,average_precision_score

from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score,precision_score,\
recall_score,f1_score,roc_curve,cohen_kappa_score,matthews_corrcoef,classification_report,auc

from utils_multiclass_classifier import *
import seaborn as sns

from sklearn.preprocessing import LabelBinarizer

# %%
project = "NCI"
predictor = "retrain_mean"

result_dir = f"results_{project}/"
os.makedirs(result_dir,exist_ok=True)

# %%
df_dict = pd.read_csv("../10methylation_meta/NCI-demo_dict_10class.csv")

class_names = df_dict["DBTA_name"].values
n_class = len(class_names)
print("n_class:", n_class)
# Out:
# n_class: 10

# %%
## Demographics based model:
df1 = pd.read_csv(f"results_{project}/direct_indirect_demo_score.csv")
actual_names = df1["DBTA_name"].values
actual_idxs = np.array([np.argwhere(class_names == x)[0][0] for x in actual_names])
df1
# Out:
#      sample        idat_filename            slide_file_name  \
# 0      AA03  204920840035_R08C01    AA03_ST-21-3098_A1.ndpi
# 1      AA28  204920840047_R06C01  AA28_ST-21-2997_A1_2.ndpi
# 2      AA42  205003700054_R04C01       AA42_ST-20-6587.ndpi
# 3      AA74  204957750034_R03C01    AA74_ST-21-3231_A1.ndpi
# 4      AA93  204957750034_R05C01    AA93_ST-21-3221_A1.ndpi
# ...     ...                  ...                        ...
# 1791   Z930  204920840137_R02C01   Z930_SI-21-2751_A10.ndpi
# 1792   Z931  204920840137_R03C01   Z931_SI-21-2836_D-1.ndpi
# 1793   Z949  204920840132_R01C01    Z949_ST-21-2923_A1.ndpi
# 1794   Z952  204920840132_R04C01    Z952_ST-21-2929_A1.ndpi
# 1795   Z957  204920840138_R01C01    Z957_ST-21-2838_A1.ndpi
#
#                                slide_name       family_class  \
# 0       HGG_00002_AA03_ST-21-3098_A1.ndpi     Grade 4 glioma
# 1     HGG_00006_AA28_ST-21-2997_A1_2.ndpi     Grade 4 glioma
# 2          HGG_00010_AA42_ST-20-6587.ndpi     Grade 4 glioma
# 3       HGG_00014_AA74_ST-21-3231_A1.ndpi    Medulloblastoma
# 4       HGG_00016_AA93_ST-21-3221_A1.ndpi         Meningioma
# ...                                   ...                ...
# 1791   HGG_03076_Z930_SI-21-2751_A10.ndpi     Grade 4 glioma
# 1792   HGG_03077_Z931_SI-21-2836_D-1.ndpi  IDH-mutant glioma
# 1793    HGG_03079_Z949_ST-21-2923_A1.ndpi     Choroid plexus
# 1794    HGG_03082_Z952_ST-21-2929_A1.ndpi    Medulloblastoma
# 1795    HGG_03083_Z957_ST-21-2838_A1.ndpi    Medulloblastoma
#
#                                         family_compound  \
# 0     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 1     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 2     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 3                             MB_G3+MB_G4+MB_SHH+MB_WNT
# 4                               MNG_BEN+MNG_INT+MNG_MAL
# ...                                                 ...
# 1791  DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 1792                            A_IDH_HG+A_IDH_LG+O_IDH
# 1793                          CPC_PED_AD+CPP_AD+CPP_PED
# 1794                          MB_G3+MB_G4+MB_SHH+MB_WNT
# 1795                          MB_G3+MB_G4+MB_SHH+MB_WNT
#
#                                    DBTA_compound                  DBTA_class  \
# 0     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 1     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 2     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 3                      MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
# 4                        MNG_BEN+MNG_INT+MNG_MAL                  Meningioma
# ...                                          ...                         ...
# 1791  GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 1792                           A_IDH_HG+A_IDH_LG     Astrocytoma, IDH-mutant
# 1793                   CPC_PED_AD+CPP_AD+CPP_PED              Choroid plexus
# 1794                   MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
# 1795                   MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
#
#      DBTA_name  class_idx  ...       GBM        MB      EPEN        PA  \
# 0          GBM         20  ...  0.360684  0.004891  0.061169  0.062277
# 1          GBM         16  ...  0.453258  0.015764  0.064085  0.107517
# 2          GBM          3  ...  0.377689  0.055495  0.279745  0.021073
# 3           MB          4  ...  0.029551  0.582622  0.116761  0.102270
# 4          MEN          6  ...  0.012279  0.008099  0.050901  0.015978
# ...        ...        ...  ...       ...       ...       ...       ...
# 1791       GBM         16  ...  0.173389  0.005414  0.033061  0.221161
# 1792     A-IDH         14  ...  0.058669  0.203878  0.123746  0.040706
# 1793        CP         27  ...  0.045858  0.164491  0.104606  0.034120
# 1794        MB          2  ...  0.067823  0.508437  0.188834  0.043020
# 1795        MB          9  ...  0.010263  0.703468  0.102072  0.097020
#
#            MEN     A-IDH        CP        SE       MPE     O-IDH
# 0     0.233615  0.147761  0.004728  0.013697  0.014922  0.096254
# 1     0.028704  0.119277  0.033719  0.038099  0.029641  0.109936
# 2     0.023809  0.084188  0.030536  0.046465  0.014268  0.066733
# 3     0.010862  0.057809  0.052965  0.009547  0.021943  0.015670
# 4     0.779102  0.003384  0.043503  0.015580  0.069012  0.002160
# ...        ...       ...       ...       ...       ...       ...
# 1791  0.009255  0.314020  0.006910  0.037517  0.007092  0.192181
# 1792  0.002585  0.245123  0.076453  0.013622  0.047869  0.187348
# 1793  0.027969  0.043380  0.459660  0.019880  0.054058  0.045977
# 1794  0.009729  0.062495  0.020480  0.081803  0.007208  0.010171
# 1795  0.007637  0.023744  0.032939  0.010372  0.009894  0.002592
#
# [1796 rows x 27 columns]

# %%
## HE-based model:
df2 = pd.read_csv(f"../23.08.160Eldad_demo/{project}_raw_demo_HnE_scores.csv")
df2
# Out:
#      sample        idat_filename            slide_file_name  \
# 0      AA03  204920840035_R08C01    AA03_ST-21-3098_A1.ndpi
# 1      AA28  204920840047_R06C01  AA28_ST-21-2997_A1_2.ndpi
# 2      AA42  205003700054_R04C01       AA42_ST-20-6587.ndpi
# 3      AA74  204957750034_R03C01    AA74_ST-21-3231_A1.ndpi
# 4      AA93  204957750034_R05C01    AA93_ST-21-3221_A1.ndpi
# ...     ...                  ...                        ...
# 1791   Z930  204920840137_R02C01   Z930_SI-21-2751_A10.ndpi
# 1792   Z931  204920840137_R03C01   Z931_SI-21-2836_D-1.ndpi
# 1793   Z949  204920840132_R01C01    Z949_ST-21-2923_A1.ndpi
# 1794   Z952  204920840132_R04C01    Z952_ST-21-2929_A1.ndpi
# 1795   Z957  204920840138_R01C01    Z957_ST-21-2838_A1.ndpi
#
#                                slide_name       family_class  \
# 0       HGG_00002_AA03_ST-21-3098_A1.ndpi     Grade 4 glioma
# 1     HGG_00006_AA28_ST-21-2997_A1_2.ndpi     Grade 4 glioma
# 2          HGG_00010_AA42_ST-20-6587.ndpi     Grade 4 glioma
# 3       HGG_00014_AA74_ST-21-3231_A1.ndpi    Medulloblastoma
# 4       HGG_00016_AA93_ST-21-3221_A1.ndpi         Meningioma
# ...                                   ...                ...
# 1791   HGG_03076_Z930_SI-21-2751_A10.ndpi     Grade 4 glioma
# 1792   HGG_03077_Z931_SI-21-2836_D-1.ndpi  IDH-mutant glioma
# 1793    HGG_03079_Z949_ST-21-2923_A1.ndpi     Choroid plexus
# 1794    HGG_03082_Z952_ST-21-2929_A1.ndpi    Medulloblastoma
# 1795    HGG_03083_Z957_ST-21-2838_A1.ndpi    Medulloblastoma
#
#                                         family_compound  \
# 0     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 1     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 2     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 3                             MB_G3+MB_G4+MB_SHH+MB_WNT
# 4                               MNG_BEN+MNG_INT+MNG_MAL
# ...                                                 ...
# 1791  DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 1792                            A_IDH_HG+A_IDH_LG+O_IDH
# 1793                          CPC_PED_AD+CPP_AD+CPP_PED
# 1794                          MB_G3+MB_G4+MB_SHH+MB_WNT
# 1795                          MB_G3+MB_G4+MB_SHH+MB_WNT
#
#                                    DBTA_compound                  DBTA_class  \
# 0     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 1     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 2     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 3                      MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
# 4                        MNG_BEN+MNG_INT+MNG_MAL                  Meningioma
# ...                                          ...                         ...
# 1791  GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 1792                           A_IDH_HG+A_IDH_LG     Astrocytoma, IDH-mutant
# 1793                   CPC_PED_AD+CPP_AD+CPP_PED              Choroid plexus
# 1794                   MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
# 1795                   MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
#
#      DBTA_name  class_idx  ...     A-IDH        CP      EPEN       GBM  \
# 0          GBM         20  ...  0.021068  0.001314  0.007784  0.927336
# 1          GBM         16  ...  0.013268  0.000174  0.001938  0.962121
# 2          GBM          3  ...  0.019338  0.000895  0.218171  0.525171
# 3           MB          4  ...  0.000847  0.001097  0.017587  0.000563
# 4          MEN          6  ...  0.000683  0.001408  0.003356  0.000841
# ...        ...        ...  ...       ...       ...       ...       ...
# 1791       GBM         16  ...  0.356493  0.000563  0.006734  0.110786
# 1792     A-IDH         14  ...  0.376559  0.002814  0.370606  0.084706
# 1793        CP         27  ...  0.002730  0.949541  0.014124  0.001893
# 1794        MB          2  ...  0.003150  0.001747  0.026503  0.002187
# 1795        MB          9  ...  0.000441  0.000462  0.004061  0.000202
#
#             MB       MEN       MPE     O-IDH        PA        SE
# 0     0.000310  0.007381  0.001438  0.009797  0.022942  0.000630
# 1     0.000175  0.000207  0.000244  0.016723  0.004675  0.000476
# 2     0.000994  0.001044  0.000996  0.224803  0.003556  0.005032
# 3     0.972209  0.000521  0.000562  0.000431  0.004558  0.001626
# 4     0.001141  0.986907  0.001778  0.000794  0.001521  0.001572
# ...        ...       ...       ...       ...       ...       ...
# 1791  0.001267  0.000699  0.000532  0.269426  0.251625  0.001876
# 1792  0.011732  0.000879  0.001000  0.130137  0.020198  0.001369
# 1793  0.018319  0.002439  0.002762  0.002239  0.003499  0.002454
# 1794  0.942404  0.001387  0.001279  0.001371  0.005318  0.014653
# 1795  0.992359  0.000334  0.000322  0.000253  0.001025  0.000541
#
# [1796 rows x 23 columns]

# %%
#df2 = df2[df2["slide_name"].isin(df1["slide_name"].values)].reset_index(drop=True)
#df2

# %%
np.mean(df1["slide_name"].values == df2["slide_name"].values)
# Out:
# 1.0

# %%
pred_scores1 = df1[class_names].values
pred_scores2 = df2[class_names].values

pred_scores1_sum = np.sum(pred_scores1,axis=1)[:,np.newaxis]
pred_scores1 = pred_scores1/pred_scores1_sum

pred_scores2_sum = np.sum(pred_scores2,axis=1)[:,np.newaxis]
pred_scores2 = pred_scores2/pred_scores2_sum

pred_scores = (pred_scores1 + pred_scores2)/2

# %%
pred_idxs = np.argmax(pred_scores, axis=1)
acc = np.mean(actual_idxs == pred_idxs)
print(f"combined, acc: {acc}")
# Out:
# combined, acc: 0.8841870824053452

# %%
def find_topk_idxs(pred_scores, topk=5):
    ## increased sort
    i = np.argsort(pred_scores,axis=1) 

    ## decreased sort
    i1 = np.flip(i, axis=1)

    ## select top k
    top_idx = i1[:, :topk]
    
    return top_idx

# %%
topk_idxs = find_topk_idxs(pred_scores, topk=5)
print(topk_idxs.shape)

all_topk_pred_names = class_names[topk_idxs]
print(all_topk_pred_names.shape)
# Out:
# (1796, 5)
# (1796, 5)

# %%
#df_meta = pd.read_csv(f"../10methylation_meta/{project}_slide_selected.csv")
n_cols_meta = df1.shape[1]- (n_class + 5)
df_meta = df1.iloc[:,:n_cols_meta].copy()
df_meta
# Out:
#      sample        idat_filename            slide_file_name  \
# 0      AA03  204920840035_R08C01    AA03_ST-21-3098_A1.ndpi
# 1      AA28  204920840047_R06C01  AA28_ST-21-2997_A1_2.ndpi
# 2      AA42  205003700054_R04C01       AA42_ST-20-6587.ndpi
# 3      AA74  204957750034_R03C01    AA74_ST-21-3231_A1.ndpi
# 4      AA93  204957750034_R05C01    AA93_ST-21-3221_A1.ndpi
# ...     ...                  ...                        ...
# 1791   Z930  204920840137_R02C01   Z930_SI-21-2751_A10.ndpi
# 1792   Z931  204920840137_R03C01   Z931_SI-21-2836_D-1.ndpi
# 1793   Z949  204920840132_R01C01    Z949_ST-21-2923_A1.ndpi
# 1794   Z952  204920840132_R04C01    Z952_ST-21-2929_A1.ndpi
# 1795   Z957  204920840138_R01C01    Z957_ST-21-2838_A1.ndpi
#
#                                slide_name       family_class  \
# 0       HGG_00002_AA03_ST-21-3098_A1.ndpi     Grade 4 glioma
# 1     HGG_00006_AA28_ST-21-2997_A1_2.ndpi     Grade 4 glioma
# 2          HGG_00010_AA42_ST-20-6587.ndpi     Grade 4 glioma
# 3       HGG_00014_AA74_ST-21-3231_A1.ndpi    Medulloblastoma
# 4       HGG_00016_AA93_ST-21-3221_A1.ndpi         Meningioma
# ...                                   ...                ...
# 1791   HGG_03076_Z930_SI-21-2751_A10.ndpi     Grade 4 glioma
# 1792   HGG_03077_Z931_SI-21-2836_D-1.ndpi  IDH-mutant glioma
# 1793    HGG_03079_Z949_ST-21-2923_A1.ndpi     Choroid plexus
# 1794    HGG_03082_Z952_ST-21-2929_A1.ndpi    Medulloblastoma
# 1795    HGG_03083_Z957_ST-21-2838_A1.ndpi    Medulloblastoma
#
#                                         family_compound  \
# 0     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 1     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 2     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 3                             MB_G3+MB_G4+MB_SHH+MB_WNT
# 4                               MNG_BEN+MNG_INT+MNG_MAL
# ...                                                 ...
# 1791  DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 1792                            A_IDH_HG+A_IDH_LG+O_IDH
# 1793                          CPC_PED_AD+CPP_AD+CPP_PED
# 1794                          MB_G3+MB_G4+MB_SHH+MB_WNT
# 1795                          MB_G3+MB_G4+MB_SHH+MB_WNT
#
#                                    DBTA_compound                  DBTA_class  \
# 0     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 1     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 2     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 3                      MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
# 4                        MNG_BEN+MNG_INT+MNG_MAL                  Meningioma
# ...                                          ...                         ...
# 1791  GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 1792                           A_IDH_HG+A_IDH_LG     Astrocytoma, IDH-mutant
# 1793                   CPC_PED_AD+CPP_AD+CPP_PED              Choroid plexus
# 1794                   MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
# 1795                   MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
#
#      DBTA_name  class_idx  count     NCI_class
# 0          GBM         20     53  GBM_MES_ATYP
# 1          GBM         16     64      GBM_RTK1
# 2          GBM          3    102      GBM_RTK2
# 3           MB          4     97         MB_G4
# 4          MEN          6     92       MNG_BEN
# ...        ...        ...    ...           ...
# 1791       GBM         16     64      GBM_RTK1
# 1792     A-IDH         14     66      A_IDH_HG
# 1793        CP         27     38    CPC_PED_AD
# 1794        MB          2    116        MB_SHH
# 1795        MB          9     74         MB_G3
#
# [1796 rows x 12 columns]

# %%
n_cols_meta = df_meta.shape[1]
df_meta[class_names] = pred_scores
for i in range(5):
    df_meta.insert(n_cols_meta+i, f"top{i+1}_pred_name", all_topk_pred_names[:,i])
    
df_meta
# Out:
#      sample        idat_filename            slide_file_name  \
# 0      AA03  204920840035_R08C01    AA03_ST-21-3098_A1.ndpi
# 1      AA28  204920840047_R06C01  AA28_ST-21-2997_A1_2.ndpi
# 2      AA42  205003700054_R04C01       AA42_ST-20-6587.ndpi
# 3      AA74  204957750034_R03C01    AA74_ST-21-3231_A1.ndpi
# 4      AA93  204957750034_R05C01    AA93_ST-21-3221_A1.ndpi
# ...     ...                  ...                        ...
# 1791   Z930  204920840137_R02C01   Z930_SI-21-2751_A10.ndpi
# 1792   Z931  204920840137_R03C01   Z931_SI-21-2836_D-1.ndpi
# 1793   Z949  204920840132_R01C01    Z949_ST-21-2923_A1.ndpi
# 1794   Z952  204920840132_R04C01    Z952_ST-21-2929_A1.ndpi
# 1795   Z957  204920840138_R01C01    Z957_ST-21-2838_A1.ndpi
#
#                                slide_name       family_class  \
# 0       HGG_00002_AA03_ST-21-3098_A1.ndpi     Grade 4 glioma
# 1     HGG_00006_AA28_ST-21-2997_A1_2.ndpi     Grade 4 glioma
# 2          HGG_00010_AA42_ST-20-6587.ndpi     Grade 4 glioma
# 3       HGG_00014_AA74_ST-21-3231_A1.ndpi    Medulloblastoma
# 4       HGG_00016_AA93_ST-21-3221_A1.ndpi         Meningioma
# ...                                   ...                ...
# 1791   HGG_03076_Z930_SI-21-2751_A10.ndpi     Grade 4 glioma
# 1792   HGG_03077_Z931_SI-21-2836_D-1.ndpi  IDH-mutant glioma
# 1793    HGG_03079_Z949_ST-21-2923_A1.ndpi     Choroid plexus
# 1794    HGG_03082_Z952_ST-21-2929_A1.ndpi    Medulloblastoma
# 1795    HGG_03083_Z957_ST-21-2838_A1.ndpi    Medulloblastoma
#
#                                         family_compound  \
# 0     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 1     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 2     DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 3                             MB_G3+MB_G4+MB_SHH+MB_WNT
# 4                               MNG_BEN+MNG_INT+MNG_MAL
# ...                                                 ...
# 1791  DMG_K27+GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_...
# 1792                            A_IDH_HG+A_IDH_LG+O_IDH
# 1793                          CPC_PED_AD+CPP_AD+CPP_PED
# 1794                          MB_G3+MB_G4+MB_SHH+MB_WNT
# 1795                          MB_G3+MB_G4+MB_SHH+MB_WNT
#
#                                    DBTA_compound                  DBTA_class  \
# 0     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 1     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 2     GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 3                      MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
# 4                        MNG_BEN+MNG_INT+MNG_MAL                  Meningioma
# ...                                          ...                         ...
# 1791  GBM_MES_ATYP+GBM_MES_TYP+GBM_RTK1+GBM_RTK2  Glioblastoma, IDH-wildtype
# 1792                           A_IDH_HG+A_IDH_LG     Astrocytoma, IDH-mutant
# 1793                   CPC_PED_AD+CPP_AD+CPP_PED              Choroid plexus
# 1794                   MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
# 1795                   MB_G3+MB_G4+MB_SHH+MB_WNT             Medulloblastoma
#
#      DBTA_name  class_idx  ...       GBM        MB      EPEN        PA  \
# 0          GBM         20  ...  0.644010  0.002601  0.034477  0.042610
# 1          GBM         16  ...  0.707689  0.007970  0.033012  0.056096
# 2          GBM          3  ...  0.451430  0.028245  0.248958  0.012314
# 3           MB          4  ...  0.015057  0.777415  0.067174  0.053414
# 4          MEN          6  ...  0.006560  0.004620  0.027128  0.008750
# ...        ...        ...  ...       ...       ...       ...       ...
# 1791       GBM         16  ...  0.142087  0.003341  0.019897  0.236393
# 1792     A-IDH         14  ...  0.071688  0.107805  0.247176  0.030452
# 1793        CP         27  ...  0.023875  0.091405  0.059365  0.018810
# 1794        MB          2  ...  0.035005  0.725421  0.107669  0.024169
# 1795        MB          9  ...  0.005233  0.847914  0.053066  0.049022
#
#            MEN     A-IDH        CP        SE       MPE     O-IDH
# 0     0.120498  0.084414  0.003021  0.007164  0.008180  0.053026
# 1     0.014456  0.066273  0.016946  0.019287  0.014942  0.063329
# 2     0.012426  0.051763  0.015716  0.025748  0.007632  0.145768
# 3     0.005691  0.029328  0.027031  0.005586  0.011252  0.008050
# 4     0.883004  0.002034  0.022456  0.008576  0.035395  0.001477
# ...        ...       ...       ...       ...       ...       ...
# 1791  0.004977  0.335257  0.003737  0.019696  0.003812  0.230803
# 1792  0.001732  0.310841  0.039633  0.007495  0.024435  0.158743
# 1793  0.015204  0.023055  0.704600  0.011167  0.028410  0.024108
# 1794  0.005558  0.032823  0.011113  0.048228  0.004243  0.005771
# 1795  0.003986  0.012093  0.016700  0.005456  0.005108  0.001422
#
# [1796 rows x 27 columns]

# %%
df_meta.to_csv(f"{result_dir}{predictor}_score.csv", index = None)
